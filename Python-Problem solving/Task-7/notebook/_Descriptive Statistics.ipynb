# %% [markdown]
# #                                  Descriptive Statistics

# %% [markdown]
# Descriptive statistics is a way of analyzing and identifying the basic features of a data set.
# Descriptive statistics provide summaries and descriptions of the data, as well as a way to visualize
# the data. A lot of raw information is difficult to review, summarize and communicate. With descriptive
# statistics, you can present the data in a meaningful way

# %% [markdown]
# ## Measure Of Central Tendency

# %% [markdown]
# The measure of central tendency is a single value that attempts to describe the whole set of data.
# There are three main features of central tendency

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## MEAN

# %% [markdown]
# The Arithmetic mean is the average of group of numbers and is computed by summing all the numbers and
# dividing by the number of numbers.The Arithmetic mean is usually just called a mean.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Population Mean is the mean of all the values in the population.It is given by the formula

# %% [markdown]
# \mu=\frac{\sum_{i=1}^{N}{x_{i}}}{N}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                   N is the number of terms in the population

# %% [markdown]
# Sample Mean is the mean of sample values collected.It is given by the formula

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                Here n is the number of terms in the sample

# %% [markdown]
# Example:
#     ![image.png](attachment:image.png)

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm,skew
import seaborn as sns
import statistics
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset and display first 5 Rows
data=pd.read_csv("data.csv")
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
# Finding null values
data.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
# Removing categorical values to calculate mean
col = data.select_dtypes(exclude = 'object').columns
col
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'No_of_Earning_Members'],
#       dtype='object')

# %%
# Calculating mean
data[col].mean()
# Out:
# Mthly_HH_Income           41558.00
# Mthly_HH_Expense          18818.00
# No_of_Fly_Members             4.06
# Emi_or_Rent_Amt            3060.00
# Annual_HH_Income         490019.04
# No_of_Earning_Members         1.46
# dtype: float64

# %% [markdown]
# ## Median

# %% [markdown]
# The median of a Dataset is the value that's is exactly in the middle when it is ordered from
# low to high or high to low.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Numerical columns to find median
col
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'No_of_Earning_Members'],
#       dtype='object')

# %%
data[col].median()
# Out:
# Mthly_HH_Income           35000.0
# Mthly_HH_Expense          15500.0
# No_of_Fly_Members             4.0
# Emi_or_Rent_Amt               0.0
# Annual_HH_Income         447420.0
# No_of_Earning_Members         1.0
# dtype: float64

# %% [markdown]
# ## Mode

# %% [markdown]
# The Mode is the most frequently occuring value in the dataset.It's possible to have no mode,one mode
# or more than one mode.
# Mode can be found for both categorical and numerical data.

# %%
data.mode()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0            45000             25000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0            590400                 Graduate                      1

# %% [markdown]
# ## Variance

# %% [markdown]
# The variance is a measure of variability.Variance tells us the degree of spread in your dataset. The
# more spread the data,the larger the variance is in relation to the mean.
# It is calculated by taking the average of squared deviations from the mean.
# Different formulaes are used for calculating the variance depending on whethe you have data from whole population or sample.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data[col].var()
# Out:
# Mthly_HH_Income          6.811009e+08
# Mthly_HH_Expense         1.461733e+08
# No_of_Fly_Members        2.302449e+00
# Emi_or_Rent_Amt          3.895551e+07
# Annual_HH_Income         1.024869e+11
# No_of_Earning_Members    5.391837e-01
# dtype: float64

# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# The spread of statistical data is measured by the standard deviation. Distribution measures the
# deviation of data from its mean or average position. The degree of dispersion is computed by the
# method of estimating the deviation of data points. It is denoted by the symbol, ‘σ’.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data[col].std()
# Out:
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# It provides direction and magnitude of linear relationship between variables It ranges from -1 to +1
# where -1 indicates strong negative correlation and +1 indicates strong positive correlation.
# If corr(x,y)> 0 => Positive correlation.
# If corr(x,y)< 0 => Negative correlation.
# corr(x,y) = corr(y,x)
# corr(x,x) = corr(y,y) = 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.corrcoef(data['Mthly_HH_Income'],data['Mthly_HH_Expense'])
# Out:
# array([[1.        , 0.64921525],
#        [0.64921525, 1.        ]])

# %%
x = np.array(data['Mthly_HH_Income'])
y = np.array(data['Mthly_HH_Expense'])

# %%
plt.title('Correlation')

plt.scatter(x,y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))
         (np.unique(x)), color='red')

plt.xlabel('Monthly Income')
plt.ylabel('Monthly Expense')

plt.show()

# %%
corrmat = data.corr()
  
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# Frequency distributions are all shapes, but a statistically normal frequency distribution has the
# mean as its mean, its mode, and its median and it looks like a symmetric mound or bell.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Normal Distribution Standard Deviation
# Generally, the normal distribution has any positive standard deviation. We know that the mean helps to determine the line of symmetry of a graph, whereas the standard deviation helps to know how far the data are spread out. If the standard deviation is smaller, the data are somewhat close to each other and the graph becomes narrower. If the standard deviation is larger, the data are dispersed more, and the graph becomes wider. The standard deviations are used to subdivide the area under the normal curve. Each subdivided section defines the percentage of data, which falls into the specific region of a graph.
#
# Using 1 standard deviation, the Empirical Rule states that,
# Approximately 68% of the data falls within one standard deviation of the mean.
# (i.e., Between Mean- one Standard Deviation and Mean + one standard deviation)
# Approximately 95% of the data falls within two standard deviations of the mean.
# (i.e., Between Mean- two Standard Deviation and Mean + two standard deviations)
# Approximately 99.7% of the data fall within three standard deviations of the mean.
# (i.e., Between Mean- three Standard Deviation and Mean + three standard deviations)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=data['Annual_HH_Income']
mean_x = statistics.mean(x)
sd = statistics.stdev(x)
    
plt.plot(x, norm.pdf(x, mean_x, sd))
plt.show()

# %% [markdown]
# ## Positively Skewed & Negatively Skewed Normal Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Effect on Mean, Median and Mode due to Skewness

# %% [markdown]
# If the distribution of data is skewed to the left, the mean is less than the median, which is often
# less than the mode. If the distribution of data is skewed to the right, the mode is often less than
# the median, which is less than the mean.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## QQ Plot(Quantile-Quantile)

# %% [markdown]
# When the quantiles of two variables are plotted against each other, then the plot obtained is known
# as quantile – quantile plot or qqplot. This plot provides a summary of whether the distributions of
# two variables are similar or not with respect to the locations.

# %%
import scipy.stats as stats
data_1 = np.array(data['Mthly_HH_Expense'])
z = (data_1 - np.mean(data_1))/np.std(data_1)

stats.probplot(z,dist='norm',plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# ## Box Cox

# %% [markdown]
# The Box-Cox transformation transforms our data so that it closely resembles a normal distribution.
#
# In many statistical techniques, we assume that the errors are normally distributed. This assumption allows us to construct confidence intervals and conduct hypothesis tests. By transforming your target variable, we can (hopefully) normalize our errors (if they are not already normal).
#
# Additionally, transforming our variables can improve the predictive power of our models because transformations can cut away white noise.

# %%
plt.figure(figsize = (5, 5))
data = np.random.beta(1, 3, 5000)

sns.distplot(data, color ="green")
plt.show()

# %% [markdown]
# We can use the Box-Cox transformation to transform the above into as close to a normal distribution
# as the Box-Cox transformation permits.

# %%
tdata = stats.boxcox(data)[0]
plt.figure(figsize = (8, 8))
sns.distplot(tdata, color ="green")
plt.show()
